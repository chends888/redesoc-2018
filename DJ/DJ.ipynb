# %%
import sys
sys.path.append('..')

from random import choice
from itertools import permutations

import pandas as pd
import networkx as nx
import seaborn as sns


import socnet as sn

from scipy import stats

import matplotlib.pyplot as plt

import math

import numpy as np
# Out:
# /usr/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /usr/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
sn.node_size = 10
sn.node_color = (255, 255, 255)

sn.edge_width = 1
sn.edge_color = (192, 192, 192)

sn.node_label_position = 'top center'

# %%
one_m = sn.load_graph('one-mode.gml')

# Mostra o grafo.
sn.show_graph(one_m, nlab=True)
# Out:
# ../socnet.py:59: RuntimeWarning:
#
# divide by zero encountered in double_scalars
#
# ../socnet.py:187: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# ../socnet.py:188: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# ../socnet.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# ../socnet.py:190: RuntimeWarning:
#
# invalid value encountered in double_scalars
# ...

# %%
two_m = sn.load_graph('two-mode.gml')

# Mostra o grafo.
sn.show_graph(two_m, nlab=True)
# Out:
# <div id="fb74af7b-2d4e-4317-b4ed-294b4ad530e6" style="height: 450px; width: 800px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("fb74af7b-2d4e-4317-b4ed-294b4ad530e6", [{"hoverinfo": "none", "line": {"color": "rgb(192, 192, 192)", "width": 1}, "mode": "lines", "x": [0.44143103441885045, 0.6887844972459268, null, 0.6829253199824747, 0.675790555732789, null, 0.6829253199824747, 0.6797762606453003, null, 0.44143103441885045, 0.9168456129965753, null, 0.9098057279200767, 0.9029414569480327, null, 0.9098057279200767, 0.904313838130426, null, 0.44143103441885045, 0.2657817908651065, null, 0.2704750039777954, 0.2719861096544533, null, 0.2704750039777954, 0.2772012622749994, null, 0.44143103441885045, 0.0342183270077587, null, 0.04133124173024813, 0.04709040881373573, null, 0.04133124173024813, 0.048056414496100576, null, 0.44143103441885
# ...

# %%
bc = nx.betweenness_centrality(one_m)
cc = nx.closeness_centrality(one_m)

df = pd.DataFrame({
        'Aluno(a)' : [one_m.nodes[n]['label'] for n in one_m.nodes],
        'Indegree' : [one_m.in_degree(n) for n in one_m.nodes],
        'Betweenness' : [bc[n] for n in one_m.nodes],
        'Closeness' : [cc[n] for n in one_m.nodes],
})

df.sort_values('Betweenness')
# Out:
#    Aluno(a)  Indegree  Betweenness  Closeness
# 12    Elisa         2     0.000000   0.177755
# 21    Pedro         0     0.000000   0.000000
# 17      Ale         0     0.000000   0.000000
# 16     Rios         2     0.000000   0.314881
# 13    Paulo         0     0.000000   0.000000
# 6    Carlos         1     0.000000   0.000000
# 24    Tirta         0     0.000000   0.000000
# 4      Joao         0     0.000000   0.000000
# 1      Jean         1     0.002536   0.041667
# 3       Leo         2     0.005435   0.176901
# 11     Gabs         2     0.020833   0.231801
# 5     Rapha         3     0.021739   0.310256
# 19  Antonio         3     0.038043   0.175362
# 20   Martim         2     0.045290   0.284038
# 8    Toyama         7     0.052295   0.458333
# 22      Isa         3     0.052355   0.360119
# 0    Rachel         5     0.059541   0.395425
# 18  Graicer        10     0.066486   0.468992
# 10     Hugo        12     0.087258   0.530702
# ...

# %%
pd.DataFrame({
        'Estilos' : [two_m.nodes[n]['label'] for n in two_m.nodes if two_m.out_degree(n) == 0],
        'Indegree' : [two_m.in_degree(n) for n in two_m.nodes if two_m.out_degree(n) == 0],
        
})
# Out:
#           Estilos  Indegree
# 0           Samba         3
# 1             MPB         7
# 2    Rap Nacional        10
# 3             Pop        11
# 4           K-Pop         2
# 5           Metal         7
# 6      Indie Rock         8
# 7            Funk         9
# 8       Sertanejo         8
# 9      Eletronica        19
# 10       Pop Rock        11
# 11          Disco         8
# 12          Opera         2
# 13         Pagode        10
# 14  Rock classico        11
# 15           Jazz         6
# 16          J-Pop         7
